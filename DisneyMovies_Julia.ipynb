# %%
#dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading file
all_disney_movies = 'Resources/disney_movies.csv'

# %%
#testing file
read_file = pd.read_csv(all_disney_movies)
read_file
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 3       65000000                1078510579
# 4       85000000                 920608730
# ..           ...                       ...
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936
#
# [579 rows x 6 columns]

# %%
# retrieve year and month
read_file['release_date'] = pd.to_datetime(read_file.release_date)
year = read_file['release_date'].dt.strftime("%Y")
month = read_file['release_date'].dt.strftime("%m")
day = read_file['release_date'].dt.strftime('%d')

# %%
# add year and month columns
read_file["Release Year"] = year
read_file["Release Month"] = month
read_file["Release Day"] = day
read_file.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross Release Year Release Month  \
# 0    184925485                5228953251         1937            12
# 1     84300000                2188229052         1940            02
# 2     83320000                2187090808         1940            11
# 3     65000000                1078510579         1946            11
# 4     85000000                 920608730         1950            02
#
#   Release Day
# 0          21
# 1          09
# 2          13
# 3          12
# 4          15

# %%
# filter data
clean_file = read_file.dropna(how = 'any')
clean_file = clean_file.loc[clean_file["Release Year"] >= '1990']
clean_file = clean_file.rename(columns={"movie_title":"Movie Title", "release_date":"Release Date", "genre":"Genre", "mpaa_rating":"MPAA Rating", "inflation_adjusted_gross":"Inflation-Adjusted Gross", "Release Day": "Release Day"})
clean_file = clean_file.drop(columns=["total_gross"])
clean_file = clean_file[["Movie Title", "Release Date", "Release Year", "Release Month", "Release Day", "Genre", "MPAA Rating", "Inflation-Adjusted Gross"]]
clean_file
# Out:
#                       Movie Title Release Date Release Year Release Month  \
# 85                         Stella   1990-02-02         1990            02
# 87                   Pretty Woman   1990-03-23         1990            03
# 88            Ernest Goes to Jail   1990-04-06         1990            04
# 89                Spaced Invaders   1990-04-27         1990            04
# 90                     Fire Birds   1990-05-24         1990            05
# ..                            ...          ...          ...           ...
# 574      The Light Between Oceans   2016-09-02         2016            09
# 575                Queen of Katwe   2016-09-23         2016            09
# 576                Doctor Strange   2016-11-04         2016            11
# 577                         Moana   2016-11-23         2016            11
# 578  Rogue One: A Star Wars Story   2016-12-16         2016            12
#
#     Release Day            Genre MPAA Rating  Inflation-Adjusted Gross
# 85           02            Drama       PG-13                  40077147
# 87           23  Romantic Comedy           R                 356389765
# 88           06           Comedy          PG                  49999822
# 89           27           Comedy          PG                  29964452
# 90           24           Action       PG-13                  29485923
# ..          ...              ...         ...                       ...
# 574          02            Drama       PG-13                  12545979
# 575          23            Drama          PG                   8874389
# 576          04        Adventure       PG-13                 232532923
# 577          23        Adventure          PG                 246082029
# 578          16        Adventure       PG-13                 529483936
#
# [478 rows x 8 columns]

# %%
group_file = clean_file.groupby('Release Date')
group_file.head()
# Out:
#                       Movie Title Release Date Release Year Release Month  \
# 85                         Stella   1990-02-02         1990            02
# 87                   Pretty Woman   1990-03-23         1990            03
# 88            Ernest Goes to Jail   1990-04-06         1990            04
# 89                Spaced Invaders   1990-04-27         1990            04
# 90                     Fire Birds   1990-05-24         1990            05
# ..                            ...          ...          ...           ...
# 574      The Light Between Oceans   2016-09-02         2016            09
# 575                Queen of Katwe   2016-09-23         2016            09
# 576                Doctor Strange   2016-11-04         2016            11
# 577                         Moana   2016-11-23         2016            11
# 578  Rogue One: A Star Wars Story   2016-12-16         2016            12
#
#     Release Day            Genre MPAA Rating  Inflation-Adjusted Gross
# 85           02            Drama       PG-13                  40077147
# 87           23  Romantic Comedy           R                 356389765
# 88           06           Comedy          PG                  49999822
# 89           27           Comedy          PG                  29964452
# 90           24           Action       PG-13                  29485923
# ..          ...              ...         ...                       ...
# 574          02            Drama       PG-13                  12545979
# 575          23            Drama          PG                   8874389
# 576          04        Adventure       PG-13                 232532923
# 577          23        Adventure          PG                 246082029
# 578          16        Adventure       PG-13                 529483936
#
# [478 rows x 8 columns]

# %%
groups=clean_file.groupby('Genre')['Inflation-Adjusted Gross'].mean()
groups
# Out:
# Genre
# Action                 1.486012e+08
# Adventure              1.731632e+08
# Black Comedy           5.224349e+07
# Comedy                 7.199446e+07
# Concert/Performance    5.741084e+07
# Documentary            1.271803e+07
# Drama                  5.464664e+07
# Horror                 2.506927e+07
# Musical                9.806013e+07
# Romantic Comedy        7.821326e+07
# Thriller/Suspense      9.241864e+07
# Western                7.381571e+07
# Name: Inflation-Adjusted Gross, dtype: float64

# %%
#Create line chart of all months and number of movies released each day
